# %%
# !pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in /home/studen/env/lib/python3.13/site-packages (2.32.4)
# Requirement already satisfied: beautifulsoup4 in /home/studen/env/lib/python3.13/site-packages (4.13.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/studen/env/lib/python3.13/site-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/studen/env/lib/python3.13/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/studen/env/lib/python3.13/site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/studen/env/lib/python3.13/site-packages (from requests) (2025.6.15)
# Requirement already satisfied: soupsieve>1.2 in /home/studen/env/lib/python3.13/site-packages (from beautifulsoup4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/studen/env/lib/python3.13/site-packages (from beautifulsoup4) (4.14.0)

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
import json

def get_all_links_json(url, domain, crawled_links=None):
    if crawled_links is None:
        crawled_links = set()

    urls_found = []

    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
    except Exception as e:
        print(f"Failed to retrieve {url}: {e}")
        return list(crawled_links)

    soup = BeautifulSoup(response.text, 'html.parser')
    for a_tag in soup.find_all('a', href=True):
        href = a_tag['href']
        full_url = urljoin(url, href)
        parsed_url = urlparse(full_url)

        if domain in parsed_url.netloc:
            clean_url = full_url.split('#')[0]
            if clean_url not in crawled_links:
                crawled_links.add(clean_url)
                urls_found.append(clean_url)
                print(f"Discovered: {clean_url}")
                # Recursive crawl
                get_all_links_json(clean_url, domain, crawled_links)

    return list(crawled_links)


base_url = "https://attra.ncat.org/publication/financing-your-farm-guidance-for-beginning-farmers/"
domain = "attra.ncat.org"

all_internal_links = get_all_links_json(base_url, domain)
result_json = json.dumps({
    "base_url": base_url,
    "total_links": len(all_internal_links),
    "internal_links": all_internal_links
}, indent=2)


print(result_json)
# Out:
# Discovered: https://attra.ncat.org/
# Discovered: https://attra.ncat.org/about/
# Discovered: https://attra.ncat.org/about/regions/
# Discovered: https://attra.ncat.org/about/staff/
# Discovered: https://attra.ncat.org/connect/
# Discovered: https://attra.ncat.org/events/
# Discovered: https://attra.ncat.org/annual-conference-2024/
# Discovered: https://attra.ncat.org/latino-farmer-conference/
# Discovered: https://attra.ncat.org/events/nw-lfc/
# Discovered: https://attra.ncat.org/topics/
# Discovered: https://attra.ncat.org/topics/agroforestry/
# Discovered: https://attra.ncat.org/business-and-marketing/
# Discovered: https://attra.ncat.org/climate-solutions/
# Discovered: https://attra.ncat.org/crops/
# Discovered: https://attra.ncat.org/equipment/
# Discovered: https://attra.ncat.org/farm-energy/
# Discovered: https://attra.ncat.org/farm-start-up/
# Discovered: https://attra.ncat.org/farmer-well-being/
# Discovered: https://attra.ncat.org/livestock/
# Discovered: https://attra.ncat.org/local-food-systems/
# Discovered: https://attra.ncat.org/organic-farming/
# Discovered: https://attra.ncat.org/pest-management/
# Discovered: https://attra.ncat.org/soil/
# Discovered: https://attra.ncat.org/media-hub/
# Discovered: https://attra.ncat.org/category/blog/
# Discovered: https://attra.ncat.org/category/podcast/
# Discovered: https://attra.ncat.org/category/video/
# Discovered: https://attra.ncat.org/publication-library/
# Discovered: https://attra.ncat.org/internships/
# Discovered: https://attra.ncat.org/internship-list/
# Discovered: https://attra.ncat.org/internship-form/
# Discovered: https://attra.ncat.org/wp-login.php?action=register
# Discovered: https://attra.ncat.org/wp-login.php
# Discovered: https://attra.ncat.org/wp-login.php?action=lostpassword
# Discovered: https://attra.ncat.org/donate/
# Discovered: https://attra.ncat.org/es/donar/
# Discovered: https://attra.ncat.org/es/
# Discovered: https://attra.ncat.org/es/acerca-de/
# Discovered: https://attra.ncat.org/es/acerca-de/oficinas/
# Discovered: https://attra.ncat.org/es/conectar/
# Discovered: https://attra.ncat.org/es/eventos/
# Discovered: https://attra.ncat.org/es/eventos/esnw-lfc/
# Discovered: https://attra.ncat.org/es/conferencia-de-agricultores-latinos/
# Discovered: https://attra.ncat.org/es/temas/
# Discovered: https://attra.ncat.org/es/negocios-y-marketing/
# Discovered: https://attra.ncat.org/es/soluciones-climaticas/
# Discovered: https://attra.ncat.org/es/cultivos/
# Discovered: https://attra.ncat.org/es/equipo/
# Discovered: https://attra.ncat.org/es/energia-agricola/
# Discovered: https://attra.ncat.org/es/puesta-en-marcha-de-la-granja/
# Discovered: https://attra.ncat.org/es/bienestar-del-agricultor/
# Discovered: https://attra.ncat.org/es/ganado/
# Discovered: https://attra.ncat.org/es/sistemas-alimentarios-locales/
# Discovered: https://attra.ncat.org/es/agricultura-organica/
# Discovered: https://attra.ncat.org/es/gestion-de-plagas/
# Discovered: https://attra.ncat.org/es/suelo/
# Discovered: https://attra.ncat.org/es/centro-de-medios-de-comunicacion/
# Discovered: https://attra.ncat.org/es/publicaciones/
# Discovered: https://attra.ncat.org/es/centro-de-practicas/
# Discovered: https://attra.ncat.org/es/centro-de-practicas/?s=
# Discovered: https://attra.ncat.org/es/internship-list/
# Discovered: https://attra.ncat.org/es/lista-de-pasantias/
# Discovered: https://attra.ncat.org/es/lista-de-pasantias/?s=
# Discovered: https://attra.ncat.org/post-an-internship/
# Discovered: https://attra.ncat.org/es/publicar-una-pasantia/
# Discovered: https://attra.ncat.org/es/publicar-una-pasantia/?s=
