# %%
# !pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in /home/studen/agenticenv/lib/python3.13/site-packages (2.32.4)
# Requirement already satisfied: beautifulsoup4 in /home/studen/agenticenv/lib/python3.13/site-packages (4.13.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/studen/agenticenv/lib/python3.13/site-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/studen/agenticenv/lib/python3.13/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/studen/agenticenv/lib/python3.13/site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/studen/agenticenv/lib/python3.13/site-packages (from requests) (2025.6.15)
# Requirement already satisfied: soupsieve>1.2 in /home/studen/agenticenv/lib/python3.13/site-packages (from beautifulsoup4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/studen/agenticenv/lib/python3.13/site-packages (from beautifulsoup4) (4.14.0)

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
# Starting URL
base_url = "https://www.moneymanagement.org/blog/financial-literacy-month"
domain = "moneymanagement.org"
def get_sub_urls(url, domain):
    try:
        response = requests.get(url)
        response.raise_for_status()
    except Exception as e:
        print(f"Failed to retrieve {url}: {e}")
        return []
    soup = BeautifulSoup(response.text, 'html.parser')
    links = set()
    for a_tag in soup.find_all('a', href=True):
        href = a_tag['href']
        # Make absolute URL
        full_url = urljoin(url, href)
        # Check domain
        parsed_url = urlparse(full_url)
        if domain in parsed_url.netloc:
            # Remove URL fragment
            clean_url = full_url.split('#')[0]
            links.add(clean_url)
    return list(links)
if __name__ == "__main__":
    urls = get_sub_urls(base_url, domain)
    print(f"Found {len(urls)} URLs under domain {domain}:\n")
    for u in urls:
        print(u)
# Out:
# Found 85 URLs under domain moneymanagement.org:
#
# https://www.moneymanagement.org/blog/a-quick-guide-to-step-down-spending
# https://www.moneymanagement.org/blog/how-to-calculate-your-net-worth
# https://www.moneymanagement.org/blog/flm-step-16-simplyforties-covers-commitment
# https://www.moneymanagement.org/credit-counseling
# https://www.moneymanagement.org/blog/flm-day-5-adam-k-levin-on-the-importance-of-financial-literacy
# https://www.moneymanagement.org/blog/how-to-pay-off-a-lot-of-debt-in-a-hurry
# https://www.moneymanagement.org/blog/flm-step-30-dr-robert-duvall-on-moving-forward
# https://www.moneymanagement.org/blog/flm-step-4-time-management-expert-teaches-you-how-to-set-yourself-up-for-success
# https://www.moneymanagement.org/login
# https://www.moneymanagement.org/about
# https://www.moneymanagement.org/blog/how-to-organize-your-personal-household-finances
# https://www.moneymanagement.org/blog/flm-step-25-lynnae-of-beingfrugalnet-on-documenting-your-desired-spending
# https://www.moneymanagement.org/locations
# https://www.moneymanagement.org/about/security/privacy
# https://www.moneymanagement.org/debt-management
# https://www.moneymanagement.org/blog/flm-step-26-the-debt-advisor-on-protecting-your-financial-future
# https://www.moneymanagement.org/blog/calculate-debt-to-income-ratio
# https://www.moneymanagement.org/blog/flm-step-7-jim-from-bargaineering-on-how-to-make-your-money-count
# https://www.moneymanagement.org/blog/flm-step-3-karen-mccall-talks-about-clearing-out-the-clutter
# https://www.moneymanagement.org/
# https://www.moneymanagement.org/blog/flm-step-2-gerri-detweiler-discusses-the-importance-of-assessing-your-financial-situation
# https://www.moneymanagement.org/blog/category/personal-finance
# https://www.moneymanagement.org/blog/flm-step-18-frugal-homemaker-on-where-the-money-goes
# https://www.moneymanagement.org/blog/simple-steps-lead-to-big-saving
# https://www.moneymanagement.org/blog/give-yourself-a-financial-self-exam
# https://www.moneymanagement.org/blog/flm-step-27-counting-the-cost-of-credit
# https://www.moneymanagement.org/online-counseling
# https://www.moneymanagement.org/education/workshops
# https://www.moneymanagement.org/budget-guides
# https://www.moneymanagement.org/blog/retirement-strategies
# https://www.moneymanagement.org/blog/-/media/1e3de59725474a508d3f9184c61e34a6.ashx
# https://www.moneymanagement.org/contact-us
